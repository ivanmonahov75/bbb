# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %%
inf = pd.read_csv('cut_disc_copy.csv')


res = {}
for i, j in zip(inf['h'].to_list(), inf['t'].to_list()):
    res.update({i: j})

h = np.array(list(res.keys()))
t = np.array(list(map(float, res.values())))
I = t*0.4*10**-4*(1.094 + 1.450)

# %%
plt.figure(figsize=(14, 9), dpi=300)

plt.grid(True)
plt.title(r"$I(h^2)$", fontsize=25)

plt.xlabel(r"$h^2, см^2$", fontsize=20)
plt.ylabel(r"$I, см г\tс^-1$", fontsize=20)

plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

plt.plot(list(map(lambda x : x**2, res.keys())), I*10**4, )
for i, j in zip(list(map(lambda x : x**2, res.keys())), I*10**4):
    plt.plot(i, j, 'rv')

# %%
# a, b = np.polyfit(i, list(map(lambda x : x**2, res.keys())), deg=1)

plt.figure(figsize=(14, 9), dpi=300)

plt.grid(True)
plt.title(r"$I(h^2)$", fontsize=25)
plt.xlabel(r"$h^2, см^2$", fontsize=20)
plt.ylabel(r"$I, кг*cм*c^-1$", fontsize=20)

plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

# plt.plot(list(map(lambda x : x**2, res.keys())), I*10**4)
plt.plot(list(map(lambda x : x**2, res.keys())), b + a*np.array(list(map(lambda x : x**2, res.keys()))))

for i, j in zip(list(map(lambda x : x**2, res.keys())), I*10**4):
    plt.plot(i, j, 'rv')

plt.savefig('../pictures/plot.png')

# %%
a, b = np.polyfit(list(map(lambda x : x**2, res.keys())), I*10**4, deg=1)
a, b, I
# Out:
# (0.21056529440957522,
#  31.420354620814475,
#  array([0.00311569, 0.0031455 , 0.00316433, 0.00318692, 0.00321877,
#         0.00325968, 0.00333203, 0.00340916, 0.00348905, 0.00358928,
#         0.00368951, 0.00378608, 0.00391725, 0.00403509, 0.00416219,
#         0.00429956]))

# %%
f"{(4) /(5):10.10f}
# Out:
#   Cell In[17], line 1
#     f"{(4) /(5):10.10f}
#     ^
# SyntaxError: unterminated string literal (detected at line 1)
