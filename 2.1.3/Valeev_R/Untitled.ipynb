# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
hz = np.genfromtxt('55_0.txt')

# %%
hz
# Out:
# array([ 262.5,  500. ,  742. ,  991. , 1238. , 1483. , 1733. , 1982. ,
#        2230. ])

# %%
for i, val in enumerate(hz):
    print(i+1, '&', val, '&', 10, '\\\ \\hline')
# Out:
# 1 & 262.5 & 10 \\ \hline
# 2 & 500.0 & 10 \\ \hline
# 3 & 742.0 & 10 \\ \hline
# 4 & 991.0 & 10 \\ \hline
# 5 & 1238.0 & 10 \\ \hline
# 6 & 1483.0 & 10 \\ \hline
# 7 & 1733.0 & 10 \\ \hline
# 8 & 1982.0 & 10 \\ \hline
# 9 & 2230.0 & 10 \\ \hline

# %%
x_val = np.linspace(1, 9, 9)

# %%
plt.plot(x_val, hz, color='r')
plt.errorbar(x_val, hz, yerr=10, fmt='none')
plt.grid()
plt.ylabel('f, гц')
plt.xlabel('n')
plt.savefig('213_5.jpg')

# %%
np.average((hz/x_val*0.7*2)[1::])
# Out:
# 363.0102777777778
